# %%
using QuantumCollocation
using NamedTrajectories
using TrajectoryIndexingUtils
using Flux
using ReinforcementLearning
using IntervalSets
using LinearAlgebra
using Base
using Distributions
using Statistics
using Printf
using Reexport
using Revise
using DomainSets
using CairoMakie

includet("PPO.jl")
includet("AIRL.jl")
includet("GateEnvs.jl")

# %%
RZ_traj = load_traj("RZ_pretrained.jld2")

const Units = 1e9
const MHz = 1e6 / Units
const GHz = 1e9 / Units
const ns = 1e-9 * Units
const μs = 1e-6 * Units
;


# Operators
const Paulis = Dict(
    "I" => Matrix{ComplexF64}([1 0; 0 1]),
    "X" => Matrix{ComplexF64}([0 1; 1 0]),
    "Y" => Matrix{ComplexF64}([0 im; -im 0]),
    "Z" => Matrix{ComplexF64}([1 0; 0 -1]),
)

rz_op(theta) = exp(-im/2 * theta[1] * Paulis["Z"]);

RZ = Gate(1,rz_op)

H_drives = [
     Paulis["X"],Paulis["Y"]
]
system = QuantumSystem(H_drives);
t_f = 10* ns
n_steps = 51
times = range(0, t_f, n_steps)  # Alternative: collect(0:Δt:t_f)
n_controls=1
n_qubits=1;
Δt = times[2] - times[1]

N = 11
;

# %%
Pretraining_Env = GatePretrainingEnv(
                                    system,
                                    n_steps,
                                    RZ,
                                    Δt,
                                    N,
                                    RZ_traj;
                                    dda_bound=1.5
                                    )

Training_Env = GateTrainingEnv(
                            system,
                            n_steps,
                            RZ,
                            Δt;
                            dda_bound=0.5
                            );

pretraining_𝒫 = ActorCriticPolicy(Pretraining_Env;l=[128,128])
training_𝒫 = ActorCriticPolicy(Training_Env;l=[128,128])
# Out:
# ActorCriticPolicy(Chain(Dense(14 => 128, tanh), Dense(128 => 128, tanh)), Dense(128 => 2, tanh), Dense(128 => 1, log_std_clip), Chain(Dense(14 => 128, tanh), Dense(128 => 128, tanh), Dense(128 => 1)))

# %%
expert_states = Vector{Vector{Float32}}()
expert_acts = Vector{Vector{Float32}}()
expert_new_states = Vector{Vector{Float32}}()
for idx in 1:11
    for t in 1:48
        angle = range(0,2*pi,11)[idx]
        a = RZ_traj[Symbol("a"*string(idx))][:,t]
        da = RZ_traj[Symbol("da"*string(idx))][:,t]
        dda = RZ_traj[Symbol("dda"*string(idx))][:,t]
        U = RZ_traj[Symbol(Unicode.normalize("Ũ⃗"*string(idx)))][:,t]
        push!(expert_states, vcat(U,da,a,[t/51],angle))
        push!(expert_acts, dda)
        if(t>1)
          push!(expert_new_states, expert_states[end])
        end
        if(t==48)
            angle = range(0,2*pi,11)[idx]
            a = RZ_traj[Symbol("a"*string(idx))][:,51]
            da = RZ_traj[Symbol("da"*string(idx))][:,51]
            dda = RZ_traj[Symbol("dda"*string(idx))][:,51]
            U = RZ_traj[Symbol(Unicode.normalize("Ũ⃗"*string(idx)))][:,51]
            push!(expert_new_states, vcat(U,da,a,[49/51],angle))

        end
    end
end
behavior_clone(pretraining_𝒫,expert_states,expert_acts;epochs=50000,η=5f-5)

# %%
mean(mean.([abs2.(x) for x in (pretraining_𝒫.mean_network.(pretraining_𝒫.feature_network.(expert_states))-expert_acts)]))
# Out:
# 0.31016448f0

# %%
#PPO_pretraining_𝒫,score_history = PPO(Pretraining_Env;η=3f-5,iterations=1000,n_steps=1,trajectory_batch_size=40,vf_ratio=5f-1,norm_adv = true,ϵ= 1f-1,ent_ratio=1f-3,KL_targ=1f-2,initial_policy=pretraining_𝒫,clip_grad_tresh=1f3,use_log_rewards=false)

# %%
#using CairoMakie
#fig = Figure()
#ax = Axis(fig[1, 1])
#lines!(ax,1:length(score_history),score_history)
#fig

# %%
includet("AIRL.jl")
AIRL_pretraining_𝒫,score_history,e_losses,s_losses,total_d_losses = AIRL(Pretraining_Env,expert_states,expert_acts,expert_new_states;η=3f-5,iterations=500,n_steps=1,trajectory_batch_size=11,vf_ratio=5f-1,norm_adv = true,ϵ= 1f-1,ent_ratio=1f-3,KL_targ=1f-2,clip_grad_tresh=1f3,use_log_rewards=false)
# Out:
# Iterations 1 Complete
# Updates 80
# Avg Score: -58.33829
# Total Steps: 528
# Total Trajectories: 11
# Final KL: 0.00520
# Mean Policy Loss: 0.01437
# Mean Value Loss: 10542.05371
# Mean Entropy: 4.01694
# Mean ADV: 58.24539
# Mean Clip Ratio: 0.12070
# Mean Discriminator Score: -4.44806
# Start Discriminator Score: -4.63864
# End Discriminator Score: -4.09499
# Discriminator Updates: 80
# Discriminator Sampled: 0.94591
# Discriminator Expert: 0.93476
# -------------------------
# Iterations 2 Complete
# Updates 80
# Avg Score: -49.95854
# Total Steps: 528
# Total Trajectories: 11
# Final KL: 0.00485
# Mean Policy Loss: 0.01117
# Mean Value Loss: 6811.64697
# Mean Entropy: 3.67181
# Mean ADV: 47.99889
# Mean Clip Ratio: 0.08906
# Mean Discriminator Score: -3.73229
# Start Discriminator Score: -3.71427
# End Discriminator Score: -3.70534
# Discriminator Updates: 80
# Discriminator Sampled: 0.92489
# Discriminator Expert: 0.92670
# -------------------------
# Iterations 3 Complete
# Updates 80
# Avg Score: -67.26513
# Total Steps: 528
# Total Trajectories: 11
# Final KL: 0.00249
# Mean Policy Loss: 0.00748
# Mean Value Loss: 8564.14648
# Mean Entropy: 4.29513
# Mean ADV: 52.05526
# Mean Clip Ratio: 0.05371
# Mean Discriminator Score: -4.05655
# Start Discriminator Score: -4.40297
# End Discriminator Score: -4.28319
# Discriminator Updates: 80
# Discriminator Sampled: 0.93186
# Discriminator Expert: 0.91252
# -------------------------
# Iterations 4 Complete
# Updates 80
# Avg Score: -58.12835
# Total Steps: 528
# Total Trajectories: 11
# Final KL: 0.00271
# Mean Policy Loss: 0.01009
# Mean Value Loss: 5741.16748
# Mean Entropy: 4.26883
# Mean ADV: 43.29819
# Mean Clip Ratio: 0.08809
# Mean Discriminator Score: -3.60657
# Start Discriminator Score: -3.89613
# End Discriminator Score: -3.18108
# Discriminator Updates: 80
# Discriminator Sampled: 0.91195
# Discriminator Expert: 0.89645
# -------------------------
# Iterations 5 Complete
# Updates 80
# Avg Score: -70.49730
# Total Steps: 528
# Total Trajectories: 11
# Final KL: 0.00431
# Mean Policy Loss: 0.01280
# Mean Value Loss: 5427.67480
# Mean Entropy: 4.25519
# Mean ADV: 42.73700
# Mean Clip Ratio: 0.09316
# Mean Discriminator Score: -3.49175
# Start Discriminator Score: -3.59069
# End Discriminator Score: -3.13401
# Discriminator Updates: 80
# Discriminator Sampled: 0.91076
# Discriminator Expert: 0.87495
# -------------------------
# (ActorCriticPolicy(Chain(Dense(14 => 128, tanh), Dense(128 => 128, tanh)), Dense(128 => 2, tanh), Dense(128 => 1, log_std_clip), Chain(Dense(14 => 128, tanh), Dense(128 => 128, tanh), Dense(128 => 1))), Float32[-58.33829, -49.95854, -67.26513, -58.128353, -70.4973], Float32[-0.06015159, -0.060246915, -0.060385622, -0.06050804, -0.060623452, -0.060731564, -0.060829878, -0.06093422, -0.061034802, -0.061131917  …  -0.1314964, -0.13184938, -0.13219161, -0.13253592, -0.13288642, -0.13324031, -0.13359874, -0.1339421, -0.13428567, -0.13463925], Float32[-4.5784883, -4.3492274, -4.4893074, -4.7264934, -4.7888813, -4.2948375, -4.539864, -4.73936, -4.580809, -4.3135486  …  -3.2915196, -3.109916, -3.0340416, -3.1458485, -3.60542, -3.3423495, -3.247611, -3.2592466, -3.3699493, -2.9993756], Float32[-4.63864, -4.4094744, -4.549693, -4.7870016, -4.849505, -4.355569, -4.6006937, -4.800294, -4.641844, -4.3746805  …  -3.423016, -3.2417653, -3.1662333, -3.2783844, -3.7383065, -3.4755898, -3.3812099, -3.3931887, -3.504235, -3.1340148])

# %%
using CairoMakie
fig = Figure()
ax = Axis(fig[1, 1])
lines!(ax,1:length(score_history),score_history)
fig

# %%
using CairoMakie
fig = Figure()
ax = Axis(fig[1, 1])
lines!(ax,1:length(e_losses),e_losses)
fig

# %%
using CairoMakie
fig = Figure()
ax = Axis(fig[1, 1])
lines!(ax,1:length(s_losses),s_losses)
fig

# %%
using CairoMakie
fig = Figure()
ax = Axis(fig[1, 1])
lines!(ax,1:length(total_d_losses),total_d_losses)
fig

# %%
includet("AIRL.jl")
bc_AIRL_pretraining_𝒫,score_history,e_losses,s_losses,total_d_losses = AIRL(Pretraining_Env,expert_states,expert_acts,expert_new_states;η=3f-5,iterations=500,n_steps=1,trajectory_batch_size=11,vf_ratio=5f-1,norm_adv = true,ϵ= 1f-1,ent_ratio=1f-3,KL_targ=1f-2,initial_policy=pretraining_𝒫,clip_grad_tresh=1f3,use_log_rewards=false)

# %%
using CairoMakie
fig = Figure()
ax = Axis(fig[1, 1])
lines!(ax,1:length(score_history),score_history)
fig

# %%
using CairoMakie
fig = Figure()
ax = Axis(fig[1, 1])
lines!(ax,1:length(e_losses),e_losses)
fig

# %%
using CairoMakie
fig = Figure()
ax = Axis(fig[1, 1])
lines!(ax,1:length(s_losses),s_losses)
fig

# %%
using CairoMakie
fig = Figure()
ax = Axis(fig[1, 1])
lines!(ax,1:length(total_d_losses),total_d_losses)
fig
