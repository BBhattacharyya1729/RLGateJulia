# %%
using QuantumCollocation
using NamedTrajectories
using TrajectoryIndexingUtils
using Flux
using ReinforcementLearning
using IntervalSets
using LinearAlgebra
using Base
using Distributions
using Statistics
using Printf
using Reexport
using Revise
using DomainSets
using CairoMakie

includet("PPO.jl")
includet("AIRL.jl")

# %%
function RLBase.act!(env::CartPoleEnv, a::Vector{Float32})
    RLBase.act!(env,a[1])
end

RLBase.action_space(env::CartPoleEnv) = (-Inf..Inf)


function RLBase.reward(env::CartPoleEnv,action::Union{Vector{Float32},Nothing};kwargs...)
    return Float32(RLBase.reward(env))
end

# %%
env = CartPoleEnv(;T=Float64,continuous=true)
history_list = []
expert_𝒫,score_history = PPO(env;η=3f-4,iterations=50,vf_ratio=5f-1,norm_adv = true,ϵ= 2f-1,ent_ratio=1f-3,KL_targ=5f-2,l=[64,64],stop_score=2.01f2)
# Out:
# Iterations 1 Complete
# Updates 320
# Avg Score: 18.83486
# Total Steps: 2053
# Total Trajectories: 109
# Final KL: 0.00870
# Mean Policy Loss: 0.00957
# Mean Value Loss: 119.19005
# Mean Entropy: 1.46084
# Mean ADV: 8.72435
# Mean Clip Ratio: 0.05044
# -------------------------
# Iterations 2 Complete
# Updates 320
# Avg Score: 21.08163
# Total Steps: 2066
# Total Trajectories: 98
# Final KL: 0.00987
# Mean Policy Loss: 0.01587
# Mean Value Loss: 73.25592
# Mean Entropy: 1.39879
# Mean ADV: 7.79776
# Mean Clip Ratio: 0.08525
# -------------------------
# Iterations 3 Complete
# Updates 320
# Avg Score: 25.68750
# Total Steps: 2055
# Total Trajectories: 80
# Final KL: 0.02027
# Mean Policy Loss: 0.02518
# Mean Value Loss: 109.88567
# Mean Entropy: 1.42334
# Mean ADV: 6.48133
# Mean Clip Ratio: 0.13569
# -------------------------
# Iterations 4 Complete
# Updates 330
# Avg Score: 39.05455
# Total Steps: 2148
# Total Trajectories: 55
# Final KL: 0.02045
# Mean Policy Loss: 0.02651
# Mean Value Loss: 208.24960
# Mean Entropy: 1.42762
# Mean ADV: 7.63090
# Mean Clip Ratio: 0.15014
# -------------------------
# Iterations 5 Complete
# Updates 320
# Avg Score: 72.03448
# Total Steps: 2089
# Total Trajectories: 29
# Final KL: 0.01360
# Mean Policy Loss: 0.01882
# Mean Value Loss: 444.62930
# Mean Entropy: 1.42497
# Mean ADV: 10.97548
# Mean Clip Ratio: 0.08867
# -------------------------
# Iterations 6 Complete
# Updates 360
# Avg Score: 117.00000
# Total Steps: 2340
# Total Trajectories: 20
# Final KL: 0.00787
# Mean Policy Loss: 0.00152
# Mean Value Loss: 472.56531
# Mean Entropy: 1.35624
# Mean ADV: 11.45662
# Mean Clip Ratio: 0.03581
# -------------------------
# Iterations 7 Complete
# Updates 370
# Avg Score: 120.60000
# Total Steps: 2412
# Total Trajectories: 20
# Final KL: 0.01525
# Mean Policy Loss: 0.00612
# Mean Value Loss: 444.01639
# Mean Entropy: 1.31862
# Mean ADV: 10.52090
# Mean Clip Ratio: 0.05300
# -------------------------
# Iterations 8 Complete
# Updates 520
# Avg Score: 169.05000
# Total Steps: 3381
# Total Trajectories: 20
# Final KL: 0.01322
# Mean Policy Loss: 0.00159
# Mean Value Loss: 468.11606
# Mean Entropy: 1.30273
# Mean ADV: 11.52458
# Mean Clip Ratio: 0.02930
# -------------------------
# Iterations 9 Complete
# Updates 590
# Avg Score: 189.75000
# Total Steps: 3795
# Total Trajectories: 20
# Final KL: 0.00285
# Mean Policy Loss: -0.00066
# Mean Value Loss: 308.17615
# Mean Entropy: 1.25588
# Mean ADV: 8.21400
# Mean Clip Ratio: 0.01629
# -------------------------
# Iterations 10 Complete
# Updates 540
# Avg Score: 174.89999
# Total Steps: 3498
# Total Trajectories: 20
# Final KL: 0.01420
# Mean Policy Loss: 0.00357
# Mean Value Loss: 285.66125
# Mean Entropy: 1.26881
# Mean ADV: 5.59242
# Mean Clip Ratio: 0.04601
# -------------------------
# Iterations 11 Complete
# Updates 600
# Avg Score: 194.10001
# Total Steps: 3882
# Total Trajectories: 20
# Final KL: 0.00238
# Mean Policy Loss: 0.00094
# Mean Value Loss: 290.52237
# Mean Entropy: 1.25285
# Mean ADV: 6.40100
# Mean Clip Ratio: 0.01932
# -------------------------
# Iterations 12 Complete
# Updates 600
# Avg Score: 192.70000
# Total Steps: 3854
# Total Trajectories: 20
# Final KL: 0.00500
# Mean Policy Loss: 0.00086
# Mean Value Loss: 284.96460
# Mean Entropy: 1.28695
# Mean ADV: 5.91257
# Mean Clip Ratio: 0.02529
# -------------------------
# Iterations 13 Complete
# Updates 620
# Avg Score: 200.60001
# Total Steps: 4012
# Total Trajectories: 20
# Final KL: 0.00955
# Mean Policy Loss: 0.00328
# Mean Value Loss: 354.51495
# Mean Entropy: 1.24117
# Mean ADV: 5.35022
# Mean Clip Ratio: 0.02780
# -------------------------
# Iterations 14 Complete
# Updates 620
# Avg Score: 201.00000
# Total Steps: 4020
# Total Trajectories: 20
# Final KL: 0.00558
# Mean Policy Loss: 0.00161
# Mean Value Loss: 322.66214
# Mean Entropy: 1.19618
# Mean ADV: 6.88283
# Mean Clip Ratio: 0.02545
# -------------------------
# (ActorCriticPolicy(Chain(Dense(4 => 64, tanh), Dense(64 => 64, tanh)), Dense(64 => 1, tanh), Dense(64 => 1, log_std_clip), Chain(Dense(4 => 64, tanh), Dense(64 => 64, tanh), Dense(64 => 1))), Float32[18.834862, 21.081633, 25.6875, 39.054546, 72.034485, 117.0, 120.6, 169.05, 189.75, 174.9, 194.1, 192.7, 200.6, 201.0])

# %%
##### using CairoMakie
fig = Figure()
ax = Axis(fig[1, 1])
lines!(ax,1:length(score_history),score_history)
fig

# %%
expert_states = Vector{Vector{Float32}}()
expert_acts = Vector{Vector{Float32}}()
expert_new_states= Vector{Vector{Float32}}()
scores = Vector{Float32}()
for i in 1:20
    r,a,s,ns = sas_sample(expert_𝒫,env;deterministic=true)
    expert_states = vcat(expert_states,s)
    expert_acts = vcat(expert_acts,a)
    expert_new_states = vcat(expert_new_states,ns)
    push!(scores,sum(r))
end
mean(scores)
# Out:
# 201.0f0

# %%
𝒫 = ActorDiscriminator(env;)
behavior_clone_𝒫 = behavior_clone(𝒫,expert_states,expert_acts;epochs=5000,η=5f-5)
# Out:
# ActorDiscriminator(Chain(Dense(5 => 64, tanh), Dense(64 => 64, tanh), Dense(64 => 1)), Chain(Dense(4 => 64, tanh), Dense(64 => 64, tanh), Dense(64 => 1)), 0.99f0, ActorCriticPolicy(Chain(Dense(4 => 64, tanh), Dense(64 => 64, tanh)), Dense(64 => 1, tanh), Dense(64 => 1, log_std_clip), Chain(Dense(4 => 64, tanh), Dense(64 => 64, tanh), Dense(64 => 1))))

# %%
AIRL_𝒫,score_history = AIRL(env,expert_states,expert_acts,expert_new_states;η=3f-4,iterations=250,vf_ratio=5f-1,norm_adv = true,ϵ= 2f-1,ent_ratio=1f-3,KL_targ=5f-2,l=[64,64],stop_score=2.01f2)
# Out:
# Iterations 1 Complete
# Updates 78
# Avg Score: 25.73750
# Total Steps: 2059
# Total Trajectories: 80
# Final KL: 0.05210
# Mean Policy Loss: -42.64610
# Mean Value Loss: 6041.57275
# Mean Entropy: 1.45047
# Mean ADV: -43.49340
# Mean Clip Ratio: 0.11118
# Mean Discriminator Score: -0.60252
# Start Discriminator Score: -1.65321
# End Discriminator Score: -0.02694
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.03296
# -------------------------
# Iterations 2 Complete
# Updates 68
# Avg Score: 17.21008
# Total Steps: 2048
# Total Trajectories: 119
# Final KL: 0.06093
# Mean Policy Loss: -46.31167
# Mean Value Loss: 4894.21875
# Mean Entropy: 1.59712
# Mean ADV: -47.33060
# Mean Clip Ratio: 0.12293
# Mean Discriminator Score: -0.01737
# Start Discriminator Score: -0.03981
# End Discriminator Score: -0.01357
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00657
# -------------------------
# Iterations 3 Complete
# Updates 303
# Avg Score: 11.84971
# Total Steps: 2050
# Total Trajectories: 173
# Final KL: 0.05033
# Mean Policy Loss: -39.55623
# Mean Value Loss: 2158.21069
# Mean Entropy: 1.79684
# Mean ADV: -40.07842
# Mean Clip Ratio: 0.07988
# Mean Discriminator Score: -0.00636
# Start Discriminator Score: -0.01009
# End Discriminator Score: -0.00197
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00314
# -------------------------
# Iterations 4 Complete
# Updates 72
# Avg Score: 10.52820
# Total Steps: 2053
# Total Trajectories: 195
# Final KL: 0.05563
# Mean Policy Loss: -39.09947
# Mean Value Loss: 1717.76465
# Mean Entropy: 1.89502
# Mean ADV: -39.62772
# Mean Clip Ratio: 0.05035
# Mean Discriminator Score: -0.00283
# Start Discriminator Score: -0.00569
# End Discriminator Score: -0.00603
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00174
# -------------------------
# Iterations 5 Complete
# Updates 157
# Avg Score: 9.61502
# Total Steps: 2048
# Total Trajectories: 213
# Final KL: 0.03069
# Mean Policy Loss: -38.87989
# Mean Value Loss: 1312.57922
# Mean Entropy: 2.15047
# Mean ADV: -39.07128
# Mean Clip Ratio: 0.11485
# Mean Discriminator Score: -0.00223
# Start Discriminator Score: -0.00176
# End Discriminator Score: -0.00047
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00133
# -------------------------
# Iterations 6 Complete
# Updates 80
# Avg Score: 9.20179
# Total Steps: 2052
# Total Trajectories: 223
# Final KL: 0.06522
# Mean Policy Loss: -40.65527
# Mean Value Loss: 1501.47510
# Mean Entropy: 2.29325
# Mean ADV: -40.41718
# Mean Clip Ratio: 0.05723
# Mean Discriminator Score: -0.00257
# Start Discriminator Score: -0.00094
# End Discriminator Score: -0.00211
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00093
# -------------------------
# Iterations 7 Complete
# Updates 41
# Avg Score: 8.76170
# Total Steps: 2059
# Total Trajectories: 235
# Final KL: 0.08909
# Mean Policy Loss: -41.30330
# Mean Value Loss: 1572.32190
# Mean Entropy: 2.37071
# Mean ADV: -42.30221
# Mean Clip Ratio: 0.06288
# Mean Discriminator Score: -0.00111
# Start Discriminator Score: -0.00118
# End Discriminator Score: -0.00027
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00061
# -------------------------
# Iterations 8 Complete
# Updates 84
# Avg Score: 7.82824
# Total Steps: 2051
# Total Trajectories: 262
# Final KL: 0.06783
# Mean Policy Loss: -38.35140
# Mean Value Loss: 1502.71350
# Mean Entropy: 2.63948
# Mean ADV: -38.97912
# Mean Clip Ratio: 0.13300
# Mean Discriminator Score: -0.00072
# Start Discriminator Score: -0.00067
# End Discriminator Score: -0.00019
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00050
# -------------------------
# Iterations 9 Complete
# Updates 20
# Avg Score: 7.54044
# Total Steps: 2051
# Total Trajectories: 272
# Final KL: 0.05199
# Mean Policy Loss: -36.62397
# Mean Value Loss: 1415.61230
# Mean Entropy: 2.85250
# Mean ADV: -37.97227
# Mean Clip Ratio: 0.17891
# Mean Discriminator Score: -0.00098
# Start Discriminator Score: -0.00584
# End Discriminator Score: -0.00010
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00039
# -------------------------
# Iterations 10 Complete
# Updates 57
# Avg Score: 6.33025
# Total Steps: 2051
# Total Trajectories: 324
# Final KL: 0.05861
# Mean Policy Loss: -32.18390
# Mean Value Loss: 969.83319
# Mean Entropy: 3.04363
# Mean ADV: -33.06445
# Mean Clip Ratio: 0.17105
# Mean Discriminator Score: -0.00078
# Start Discriminator Score: -0.00052
# End Discriminator Score: -0.00017
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00032
# -------------------------
# Iterations 11 Complete
# Updates 35
# Avg Score: 5.82153
# Total Steps: 2055
# Total Trajectories: 353
# Final KL: 0.07927
# Mean Policy Loss: -29.27896
# Mean Value Loss: 661.41675
# Mean Entropy: 3.12667
# Mean ADV: -30.91331
# Mean Clip Ratio: 0.17768
# Mean Discriminator Score: -0.00050
# Start Discriminator Score: -0.00064
# End Discriminator Score: -0.00010
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00020
# -------------------------
# Iterations 12 Complete
# Updates 28
# Avg Score: 5.12219
# Total Steps: 2054
# Total Trajectories: 401
# Final KL: 0.07357
# Mean Policy Loss: -27.08156
# Mean Value Loss: 629.26666
# Mean Entropy: 3.36885
# Mean ADV: -28.08888
# Mean Clip Ratio: 0.15960
# Mean Discriminator Score: -0.00032
# Start Discriminator Score: -0.00652
# End Discriminator Score: -0.00013
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00017
# -------------------------
# Iterations 13 Complete
# Updates 22
# Avg Score: 4.26611
# Total Steps: 2052
# Total Trajectories: 481
# Final KL: 0.07270
# Mean Policy Loss: -21.19700
# Mean Value Loss: 359.14789
# Mean Entropy: 3.55655
# Mean ADV: -21.97817
# Mean Clip Ratio: 0.16832
# Mean Discriminator Score: -0.00030
# Start Discriminator Score: -0.00021
# End Discriminator Score: -0.00033
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00013
# -------------------------
# Iterations 14 Complete
# Updates 22
# Avg Score: 3.57143
# Total Steps: 2050
# Total Trajectories: 574
# Final KL: 0.08646
# Mean Policy Loss: -16.84576
# Mean Value Loss: 218.54117
# Mean Entropy: 3.87017
# Mean ADV: -17.66385
# Mean Clip Ratio: 0.24716
# Mean Discriminator Score: -0.00019
# Start Discriminator Score: -0.00016
# End Discriminator Score: -0.00010
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00010
# -------------------------
# Iterations 15 Complete
# Updates 62
# Avg Score: 3.11381
# Total Steps: 2052
# Total Trajectories: 659
# Final KL: 0.06502
# Mean Policy Loss: -16.41861
# Mean Value Loss: 204.01480
# Mean Entropy: 4.07367
# Mean ADV: -17.48412
# Mean Clip Ratio: 0.19355
# Mean Discriminator Score: -0.00092
# Start Discriminator Score: -0.00025
# End Discriminator Score: -0.00008
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00009
# -------------------------
# Iterations 16 Complete
# Updates 74
# Avg Score: 2.90652
# Total Steps: 2052
# Total Trajectories: 706
# Final KL: 0.03332
# Mean Policy Loss: -16.16735
# Mean Value Loss: 163.28091
# Mean Entropy: 4.24823
# Mean ADV: -16.24120
# Mean Clip Ratio: 0.11486
# Mean Discriminator Score: -0.00007
# Start Discriminator Score: -0.00007
# End Discriminator Score: -0.00003
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00005
# -------------------------
# Iterations 17 Complete
# Updates 33
# Avg Score: 2.78049
# Total Steps: 2052
# Total Trajectories: 738
# Final KL: 0.20921
# Mean Policy Loss: -14.70729
# Mean Value Loss: 116.35959
# Mean Entropy: 4.42683
# Mean ADV: -14.40750
# Mean Clip Ratio: 0.11411
# Mean Discriminator Score: -0.00006
# Start Discriminator Score: -0.00003
# End Discriminator Score: -0.00004
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00004
# -------------------------
# Iterations 18 Complete
# Updates 133
# Avg Score: 2.74198
# Total Steps: 2051
# Total Trajectories: 748
# Final KL: 0.05440
# Mean Policy Loss: -13.12599
# Mean Value Loss: 91.96826
# Mean Entropy: 4.52700
# Mean ADV: -13.31779
# Mean Clip Ratio: 0.08823
# Mean Discriminator Score: -0.00007
# Start Discriminator Score: -0.00010
# End Discriminator Score: -0.00001
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00004
# -------------------------
# Iterations 19 Complete
# Updates 68
# Avg Score: 2.77027
# Total Steps: 2050
# Total Trajectories: 740
# Final KL: 0.09296
# Mean Policy Loss: -12.64378
# Mean Value Loss: 95.38366
# Mean Entropy: 4.65235
# Mean ADV: -12.81389
# Mean Clip Ratio: 0.07537
# Mean Discriminator Score: -0.00008
# Start Discriminator Score: -0.00039
# End Discriminator Score: -0.00004
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00004
# -------------------------
# Iterations 20 Complete
# Updates 65
# Avg Score: 2.83264
# Total Steps: 2048
# Total Trajectories: 723
# Final KL: 0.12534
# Mean Policy Loss: -14.81331
# Mean Value Loss: 126.42685
# Mean Entropy: 4.68700
# Mean ADV: -14.54336
# Mean Clip Ratio: 0.07933
# Mean Discriminator Score: -0.00003
# Start Discriminator Score: -0.00002
# End Discriminator Score: -0.00002
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00002
# -------------------------
# Iterations 21 Complete
# Updates 90
# Avg Score: 2.83402
# Total Steps: 2049
# Total Trajectories: 723
# Final KL: 0.08218
# Mean Policy Loss: -14.29098
# Mean Value Loss: 125.53741
# Mean Entropy: 4.79656
# Mean ADV: -14.47551
# Mean Clip Ratio: 0.10503
# Mean Discriminator Score: -0.00008
# Start Discriminator Score: -0.00002
# End Discriminator Score: -0.00002
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00002
# -------------------------
# Iterations 22 Complete
# Updates 62
# Avg Score: 2.79400
# Total Steps: 2048
# Total Trajectories: 733
# Final KL: 0.05368
# Mean Policy Loss: -14.08712
# Mean Value Loss: 112.03446
# Mean Entropy: 4.90812
# Mean ADV: -13.94858
# Mean Clip Ratio: 0.08669
# Mean Discriminator Score: -0.00002
# Start Discriminator Score: -0.00002
# End Discriminator Score: -0.00003
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00001
# -------------------------
# Iterations 23 Complete
# Updates 82
# Avg Score: 2.79781
# Total Steps: 2048
# Total Trajectories: 732
# Final KL: 0.10392
# Mean Policy Loss: -14.45480
# Mean Value Loss: 120.35496
# Mean Entropy: 5.02694
# Mean ADV: -14.50534
# Mean Clip Ratio: 0.09470
# Mean Discriminator Score: -0.00003
# Start Discriminator Score: -0.00002
# End Discriminator Score: -0.00001
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00002
# -------------------------
# Iterations 24 Complete
# Updates 237
# Avg Score: 2.73797
# Total Steps: 2048
# Total Trajectories: 748
# Final KL: 0.05026
# Mean Policy Loss: -13.37545
# Mean Value Loss: 100.63182
# Mean Entropy: 5.18859
# Mean ADV: -13.55754
# Mean Clip Ratio: 0.15144
# Mean Discriminator Score: -0.00004
# Start Discriminator Score: -0.00030
# End Discriminator Score: -0.00001
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00002
# -------------------------
# Iterations 25 Complete
# Updates 320
# Avg Score: 2.84211
# Total Steps: 2052
# Total Trajectories: 722
# Final KL: 0.01946
# Mean Policy Loss: -20.45237
# Mean Value Loss: 253.26395
# Mean Entropy: 5.32694
# Mean ADV: -20.40680
# Mean Clip Ratio: 0.04404
# Mean Discriminator Score: -0.00100
# Start Discriminator Score: -0.00002
# End Discriminator Score: -0.00000
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00000
# -------------------------
# Iterations 26 Complete
# Updates 320
# Avg Score: 2.78049
# Total Steps: 2052
# Total Trajectories: 738
# Final KL: 0.00143
# Mean Policy Loss: -19.19860
# Mean Value Loss: 191.17824
# Mean Entropy: 5.39720
# Mean ADV: -19.19129
# Mean Clip Ratio: 0.00547
# Mean Discriminator Score: -0.00001
# Start Discriminator Score: -0.00001
# End Discriminator Score: -0.00001
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00001
# -------------------------
# Iterations 27 Complete
# Updates 320
# Avg Score: 2.78639
# Total Steps: 2048
# Total Trajectories: 735
# Final KL: 0.00006
# Mean Policy Loss: -18.30250
# Mean Value Loss: 213.08342
# Mean Entropy: 5.41334
# Mean ADV: -18.30625
# Mean Clip Ratio: 0.00068
# Mean Discriminator Score: -0.00000
# Start Discriminator Score: -0.00000
# End Discriminator Score: -0.00001
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00000
# -------------------------
# Iterations 28 Complete
# Updates 320
# Avg Score: 2.83564
# Total Steps: 2053
# Total Trajectories: 724
# Final KL: 0.00004
# Mean Policy Loss: -18.14577
# Mean Value Loss: 229.78232
# Mean Entropy: 5.40193
# Mean ADV: -18.15303
# Mean Clip Ratio: 0.00059
# Mean Discriminator Score: -0.00001
# Start Discriminator Score: -0.00002
# End Discriminator Score: -0.00000
# Discriminator Updates: 320.00000
# Discriminator Sampled: 0.00001
# -------------------------
# Iterations 29 Complete
# Updates 320
# InterruptException:
#
# Stacktrace:
#   [1] try_yieldto(undo::typeof(Base.ensure_rescheduled))
#     @ Base .\task.jl:931
#   [2] wait()
#     @ Base .\task.jl:995
#   [3] uv_write(s::Base.PipeEndpoint, p::Ptr{UInt8}, n::UInt64)
#     @ Base .\stream.jl:1048
#   [4] unsafe_write(s::Base.PipeEndpoint, p::Ptr{UInt8}, n::UInt64)
#     @ Base .\stream.jl:1120
#   [5] unsafe_write
#     @ .\io.jl:431 [inlined]
#   [6] unsafe_write
#     @ .\io.jl:698 [inlined]
#   [7] write
#     @ .\io.jl:721 [inlined]
#   [8] format(io::IJulia.IJuliaStdio{Base.PipeEndpoint}, f::Printf.Format{Base.CodeUnits{UInt8, String}, Tuple{Printf.Spec{Val{'i'}}}}, args::Int64)
#     @ Printf C:\Users\Bikrant\AppData\Local\julias\julia-1.10\share\julia\stdlib\v1.10\Printf\src\Printf.jl:934
#   [9] AIRL(env::CartPoleEnv{Float64, Float64}, expert_states::Vector{Vector{Float32}}, expert_acts::Vector{Vector{Float32}}, expert_new_states::Vector{Vector{Float32}}; trajectory_batch_size::Int64, n_steps::Int64, iterations::Int64, initial_policy::ActorDiscriminator, l::Vector{Int64}, epochs::Int64, η::Float32, fit_batch_size::Int64, ϵ::Float32, verbose::Bool, γ::Float32, λ::Float32, KL_targ::Float32, clip_grad_tresh::Float32, vf_ratio::Float32, ent_ratio::Float32, norm_adv::Bool, use_log_rewards::Bool, stop_score::Float32, trajectory_kwargs::@Kwargs{})
#     @ Main C:\Users\Bikrant\PicoRL\AIRL.jl:231
#  [10] top-level scope
#     @ In[7]:1

# %%
##### using CairoMakie
fig = Figure()
ax = Axis(fig[1, 1])
lines!(ax,1:length(score_history),score_history)
fig
