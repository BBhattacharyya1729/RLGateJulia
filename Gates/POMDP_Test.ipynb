# %%
import POMDPs
using POMDPs: POMDP
using POMDPTools: Deterministic, Uniform, SparseCat

struct TigerPOMDP <: POMDP{String, String, String}
    p_correct::Float64
    indices::Dict{String, Int}

    TigerPOMDP(p_correct=0.85) = new(p_correct, Dict("left"=>1, "right"=>2, "listen"=>3))
end

POMDPs.states(m::TigerPOMDP) = ["left", "right"]
POMDPs.actions(m::TigerPOMDP) = ["left", "right", "listen"]
POMDPs.observations(m::TigerPOMDP) = ["left", "right"]
POMDPs.discount(m::TigerPOMDP) = 0.95
POMDPs.stateindex(m::TigerPOMDP, s) = m.indices[s]
POMDPs.actionindex(m::TigerPOMDP, a) = m.indices[a]
POMDPs.obsindex(m::TigerPOMDP, o) = m.indices[o]

function POMDPs.transition(m::TigerPOMDP, s, a)
    if a == "listen"
        return Deterministic(s) # tiger stays behind the same door
    else # a door is opened
        return Uniform(["left", "right"]) # reset
    end
end

function POMDPs.observation(m::TigerPOMDP, a, sp)
    if a == "listen"
        if sp == "left"
            return SparseCat(["left", "right"], [m.p_correct, 1.0-m.p_correct])
        else
            return SparseCat(["right", "left"], [m.p_correct, 1.0-m.p_correct])
        end
    else
        return Uniform(["left", "right"])
    end
end

function POMDPs.reward(m::TigerPOMDP, s, a)
    if a == "listen"
        return -1.0
    elseif s == a # the tiger was found
        return -100.0
    else # the tiger was escaped
        return 10.0
    end
end

POMDPs.initialstate(m::TigerPOMDP) = Uniform(["left", "right"])
# output
# Out:
# Precompiling POMDPs
#   ✓ InverseFunctions
#   ✓ Compat
#   ✓ FillArrays
#   ✓ Rmath_jll
#   ✓ Compat → CompatLinearAlgebraExt
#   ✓ Rmath
#   ✓ InverseFunctions → InverseFunctionsTestExt
#   ✓ FillArrays → FillArraysPDMatsExt
#   ✓ ChainRulesCore
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ DataStructures
#   ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#   ✓ SortingAlgorithms
#   ✓ StaticArrays → StaticArraysChainRulesCoreExt
#   ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#   ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#   ✓ QuadGK
#   ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#   ✓ StatsBase
#   ✓ HypergeometricFunctions
#   ✓ Graphs
#   ✓ StatsFuns
#   ✓ StatsFuns → StatsFunsInverseFunctionsExt
#   ✓ StatsFuns → StatsFunsChainRulesCoreExt
#   ✓ Distributions
#   ✓ Distributions → DistributionsTestExt
#   ✓ Distributions → DistributionsChainRulesCoreExt
#   ✓ POMDPs
#   28 dependencies successfully precompiled in 36 seconds. 35 already precompiled.
# ArgumentError: Package POMDPTools not found in current path.
# - Run `import Pkg; Pkg.add("POMDPTools")` to install the POMDPTools package.
#
# Stacktrace:
#  [1] macro expansion
#    @ .\loading.jl:1772 [inlined]
#  [2] macro expansion
#    @ .\lock.jl:267 [inlined]
#  [3] __require(into::Module, mod::Symbol)
#    @ Base .\loading.jl:1753
#  [4] #invoke_in_world#3
#    @ .\essentials.jl:926 [inlined]
#  [5] invoke_in_world
#    @ .\essentials.jl:923 [inlined]
#  [6] require(into::Module, mod::Symbol)
#    @ Base .\loading.jl:1746

# %%
using Crux
# Out:
# Precompiling Crux
#   ✓ Tricks
#   ✓ CustomUnitRanges
#   ✓ InlineStrings
#   ✓ BFloat16s
#   ✓ Functors
#   ✓ CUDA_Runtime_Discovery
#   ✓ LLVMLoopInfo
#   ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#   ✓ BufferedStreams
#   ✓ TranscodingStreams
#   ✓ RandomNumbers
#   ✓ ConstructionBase
#   ✓ CommonWorldInvalidations
#   ✓ EnzymeCore
#   ✓ ComputationalResources
#   ✓ ProgressMeter
#   ✓ Latexify
#   ✓ CommonSubexpressions
#   ✓ Tables
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ✓ CUDA_Driver_jll
#   ✓ LLVMOpenMP_jll
#   ✓ IntelOpenMP_jll
#   ✓ fzf_jll
#   ✓ XML2_jll
#   ✓ Ghostscript_jll
#   ✓ LLVMExtra_jll
#   ✓ NVTX_jll
#   ✓ JuliaNVTXCallbacks_jll
#   ✓ ZygoteRules
#   ✓ OnlineStatsBase
#   ✓ ValueHistories
#   ✓ ArrayInterface
#   ✓ LittleCMS_jll
#   ✓ libvorbis_jll
#   ✓ Unitful
#   ✓ Distances → DistancesChainRulesCoreExt
#   ✓ ZMQ
#   ✓ CoordinateTransformations
#   ✓ Interpolations
#   ✓ RegionTrees
#   ✓ Rotations
#   ✓ ColorVectorSpace
#   ✓ PyPlot
#   ✓ SimpleWeightedGraphs
#   ✓ IntegralArrays
#   ✓ CommonRLInterface
#   ✓ CatIndices
#   ✓ InlineStrings → ParsersExt
#   ✓ Optimisers
#   ✓ Polynomials
#   ✓ CodecZlib
#   ✓ ArrayLayouts
#   ✓ Random123
#   ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#   ✓ ProtoBuf
#   ✓ EnzymeCore → AdaptExt
#   ✓ Static
#   ✓ ForwardDiff
#   ✓ PrettyTables
#   ✓ CUDA_Runtime_jll
#   ✓ JLD2
#   ✓ JLFzf
#   ✓ XSLT_jll
#   ✓ Gettext_jll
#   ✓ LLVM
#   ✓ NVTX
#   ✓ OpenJpeg_jll
#   ✓ Unitful → InverseFunctionsUnitfulExt
#   ✓ TiffImages
#   ✓ Clustering
#   ✓ Rotations → RotationsRecipesBaseExt
#   ✓ Interpolations → InterpolationsUnitfulExt
# MKL_jll Waiting for background task / IO / timer.
# [pid 19868] waiting for IO to finish:
#  Handle type        uv_handle_t->data
#  timer              0000022a1f7070b0->0000022a1b58e950
# This means that a package has started a background task or event source that has not finished running. For precompilation to complete successfully, the event source needs to be closed explicitly. See the developer documentation on fixing precompilation hangs for more help.
#   ✓ ColorSchemes
#   ✓ WeightsAndBiasLogger
#   ✓ HTTP
#   ✓ ArrayLayouts → ArrayLayoutsSparseArraysExt
#   ✓ ConstructionBase → ConstructionBaseIntervalSetsExt
#   ✓ BitTwiddlingConvenienceFunctions
#
# [pid 19868] waiting for IO to finish:
#  Handle type        uv_handle_t->data
#  timer              0000022a1f7070b0->0000022a1b58e950
# This means that a package has started a background task or event source that has not finished running. For precompilation to complete successfully, the event source needs to be closed explicitly. See the developer documentation on fixing precompilation hangs for more help.
#   ✓ CPUSummary
#   ✓ ForwardDiff → ForwardDiffStaticArraysExt
#   ✓ MKL_jll
#   ✓ CUDNN_jll
#   ✓ MetaGraphs
#   ✓ Glib_jll
#   ✓ LLVM → BFloat16sExt
#   ✓ ImageMagick_jll
#   ✓ Unitful → ConstructionBaseUnitfulExt
#   ✓ ImageCore
#   ✓ PlotUtils
#   ✓ LazyArrays
#   ✓ Setfield
#   ✓ StructArrays
#   ✓ HostCPUFeatures
#   ✓ PolyesterWeave
#   ✓ FFTViews
#   ✓ Cairo_jll
#   ✓ Qt6Base_jll
#   ✓ UnsafeAtomicsLLVM
#   ✓ DataFrames
#   ✓ GPUArrays
#   ✓ PNGFiles
#   ✓ ImageBase
#   ✓ GPUCompiler
#   ✓ Sixel
#   ✓ ImageMagick
#   ✓ JpegTurbo
#   ✓ TensorBoardLogger
#   ✓ RecipesPipeline
#   ✓ LazyArrays → LazyArraysStaticArraysExt
#   ✓ SplittablesBase
#   ✓ PlotThemes
#   ✓ UnicodePlots
#   ✓ BangBang
#   ✓ StructArrays → StructArraysGPUArraysCoreExt
#   ✓ HarfBuzz_jll
#   ✓ Qt6ShaderTools_jll
#   ✓ HistogramThresholding
#   ✓ Latexify → DataFramesExt
#   ✓ KernelAbstractions
#   ✓ ImageTransformations
#   ✓ ImageAxes
#   ✓ ImageShow
#   ✓ BangBang → BangBangChainRulesCoreExt
#   ✓ StructArrays → StructArraysStaticArraysExt
#   ✓ libass_jll
#   ✓ UnicodePlots → IntervalSetsExt
#   ✓ Pango_jll
#   ✓ Latexify → SparseArraysExt
#   ✓ Qt6Declarative_jll
#   ✓ ImageBinarization
#   ✓ KernelAbstractions → SparseArraysExt
#   ✓ BangBang → BangBangStaticArraysExt
#   ✓ ImageContrastAdjustment
#   ✓ ImageMetadata
#   ✓ StructArrays → StructArraysSparseArraysExt
#   ✓ GLFW_jll
#   ✓ FFMPEG_jll
#   ✓ Qt6Wayland_jll
#   ✓ KernelAbstractions → LinearAlgebraExt
#   ✓ UnicodePlots → FreeTypeExt
#   ✓ UnitfulLatexify
#   ✓ BangBang → BangBangStructArraysExt
#   ✓ Netpbm
#   ✓ FFMPEG
#   ✓ GR_jll
#   ✓ KernelAbstractions → EnzymeExt
#   ✓ ChainRules
#   ✓ GeometryBasics
#   ✓ UnicodePlots → UnitfulExt
#   ✓ BangBang → BangBangDataFramesExt
#   ✓ GR
#   ✓ NNlib
#   ✓ ArrayInterface → ArrayInterfaceChainRulesExt
#   ✓ POMDPTools
#   ✓ MicroCollections
#   ✓ Zygote
#   ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ✓ Transducers
#   ✓ Zygote → ZygoteDistancesExt
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ✓ Transducers → TransducersDataFramesExt
#   ✓ Zygote → ZygoteColorsExt
#   ✓ Transducers → TransducersOnlineStatsBaseExt
#   ✓ Transducers → TransducersLazyArraysExt
#   ✓ CUDA
#   ✓ FLoops
#   ✓ CUDA → SpecialFunctionsExt
#   ✓ ArrayInterface → ArrayInterfaceCUDAExt
#   ✓ CUDA → ChainRulesCoreExt
#   ✓ NNlib → NNlibCUDAExt
#   ✓ StaticArrayInterface
#   ✓ NNlib → NNlibEnzymeCoreExt
#   ✓ CUDA → EnzymeCoreExt
#   ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#   ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ✓ TiledIteration
#   ✓ CloseOpenIntervals
#   ✓ LayoutPointers
#   ✓ cuDNN
#   ✓ VectorizationBase
#   ✓ Plots
#   ✓ SLEEFPirates
#   ✓ Plots → FileIOExt
#   ✓ NNlib → NNlibCUDACUDNNExt
#   ✓ Plots → UnitfulExt
#   ✓ NNlib → NNlibFFTWExt
#   ✓ Plots → GeometryBasicsExt
#   ✓ OneHotArrays
#   ✓ MLUtils
#   ✓ Plots → IJuliaExt
#   ✓ LoopVectorization
#   ✓ LoopVectorization → SpecialFunctionsExt
#   ✓ LoopVectorization → ForwardDiffExt
#   ✓ Flux
#   ✓ ImageMorphology
#   ✓ ImageDistances
#   ✓ Flux → FluxCUDAExt
#   ✓ Flux → FluxCUDAcuDNNExt
#   ✓ ImageFiltering
#   ✓ ImageSegmentation
#   ✓ ImageCorners
#   ✓ ImageQualityIndexes
#   ✓ Images
#         Info Given Crux was explicitly requested, output will be shown live
# ┌ Warning: Package cuDNN not found in current path.
# │ - Run `import Pkg; Pkg.add("cuDNN")` to install the cuDNN package, then restart julia.
# │ - If cuDNN is not installed, some Flux functionalities will not be available when running on the GPU.
# └ @ FluxCUDAExt C:\Users\Bikrant\.julia\packages\Flux\HBF2N\ext\FluxCUDAExt\FluxCUDAExt.jl:57
# ERROR: LoadError: InitError: PyError (PyImport_ImportModule
#
# The Python package wandb could not be imported by pyimport. Usually this means
# that you did not install wandb in the Python version being used by PyCall.
#
# PyCall is currently configured to use the Julia-specific Python distribution
# installed by the Conda.jl package.  To install the wandb module, you can
# use `pyimport_conda("wandb", PKG)`, where PKG is the Anaconda
# package that contains the module wandb, or alternatively you can use the
# Conda package directly (via `using Conda` followed by `Conda.add` etcetera).
#
# Alternatively, if you want to use a different Python distribution on your
# system, such as a system-wide Python (as opposed to the Julia-specific Python),
# you can re-configure PyCall with that Python.   As explained in the PyCall
# documentation, set ENV["PYTHON"] to the path/name of the python executable
# you want to use, run Pkg.build("PyCall"), and re-launch Julia.
#
# ) <class 'ModuleNotFoundError'>
# ModuleNotFoundError("No module named 'wandb'")
#
# Stacktrace:
#   [1] pyimport(name::String)
#     @ PyCall C:\Users\Bikrant\.julia\packages\PyCall\1gn3u\src\PyCall.jl:558
#   [2] __init__()
#     @ WeightsAndBiasLogger C:\Users\Bikrant\.julia\packages\WeightsAndBiasLogger\fr2H9\src\WeightsAndBiasLogger.jl:7
#   [3] run_module_init(mod::Module, i::Int64)
#     @ Base .\loading.jl:1134
#   [4] register_restored_modules(sv::Core.SimpleVector, pkg::Base.PkgId, path::String)
#     @ Base .\loading.jl:1122
#   [5] _include_from_serialized(pkg::Base.PkgId, path::String, ocachepath::String, depmods::Vector{Any})
#     @ Base .\loading.jl:1067
#   [6] _require_search_from_serialized(pkg::Base.PkgId, sourcepath::String, build_id::UInt128)
#     @ Base .\loading.jl:1581
#   [7] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1938
#   [8] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#   [9] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [10] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [11] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#  [12] macro expansion
#     @ .\loading.jl:1790 [inlined]
#  [13] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [14] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#  [15] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [16] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [17] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746
#  [18] include
#     @ .\Base.jl:495 [inlined]
#  [19] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::Nothing)
#     @ Base .\loading.jl:2222
#  [20] top-level scope
#     @ stdin:3
# during initialization of module WeightsAndBiasLogger
# in expression starting at C:\Users\Bikrant\.julia\packages\Crux\thZBC\src\Crux.jl:1
# in expression starting at stdin:3
#   ✗ Crux
#   204 dependencies successfully precompiled in 595 seconds. 255 already precompiled.
#   1 dependency precompiled but a different version is currently loaded. Restart julia to access the new version
#   2 dependencies had output during precompilation:
# ┌ MKL_jll
# │   Downloading artifact: MKL
# │  ┌ Error: curl_easy_setopt: 4
# │  └ @ Downloads.Curl C:\Users\Bikrant\AppData\Local\julias\julia-1.10\share\julia\stdlib\v1.10\Downloads\src\Curl\utils.jl:50
# │
# │  [pid 19868] waiting for IO to finish:
# │   Handle type        uv_handle_t->data
# │   timer              0000022a1f7070b0->0000022a1b58e950
# │  This means that a package has started a background task or event source that has not finished running. For precompilation to complete successfully, the event source needs to be closed explicitly. See the developer documentation on fixing precompilation hangs for more help.
# │
# │  [pid 19868] waiting for IO to finish:
# │   Handle type        uv_handle_t->data
# │   timer              0000022a1f7070b0->0000022a1b58e950
# │  This means that a package has started a background task or event source that has not finished running. For precompilation to complete successfully, the event source needs to be closed explicitly. See the developer documentation on fixing precompilation hangs for more help.
# └
# ┌ Flux → FluxCUDAcuDNNExt
# │  ┌ Warning: Package cuDNN not found in current path.
# │  │ - Run `import Pkg; Pkg.add("cuDNN")` to install the cuDNN package, then restart julia.
# │  │ - If cuDNN is not installed, some Flux functionalities will not be available when running on the GPU.
# │  └ @ FluxCUDAExt C:\Users\Bikrant\.julia\packages\Flux\HBF2N\ext\FluxCUDAExt\FluxCUDAExt.jl:57
# └
# The following 1 direct dependency failed to precompile:
#
# Crux [e51cc422-768a-4345-bb8e-2246287ae729]
#
# Failed to precompile Crux [e51cc422-768a-4345-bb8e-2246287ae729] to "C:\\Users\\Bikrant\\.julia\\compiled\\v1.10\\Crux\\jl_1BF9.tmp".
# ┌ Warning: Package cuDNN not found in current path.
# │ - Run `import Pkg; Pkg.add("cuDNN")` to install the cuDNN package, then restart julia.
# │ - If cuDNN is not installed, some Flux functionalities will not be available when running on the GPU.
# └ @ FluxCUDAExt C:\Users\Bikrant\.julia\packages\Flux\HBF2N\ext\FluxCUDAExt\FluxCUDAExt.jl:57
# ERROR: LoadError: InitError: PyError (PyImport_ImportModule
#
# The Python package wandb could not be imported by pyimport. Usually this means
# that you did not install wandb in the Python version being used by PyCall.
#
# PyCall is currently configured to use the Julia-specific Python distribution
# installed by the Conda.jl package.  To install the wandb module, you can
# use `pyimport_conda("wandb", PKG)`, where PKG is the Anaconda
# package that contains the module wandb, or alternatively you can use the
# Conda package directly (via `using Conda` followed by `Conda.add` etcetera).
#
# Alternatively, if you want to use a different Python distribution on your
# system, such as a system-wide Python (as opposed to the Julia-specific Python),
# you can re-configure PyCall with that Python.   As explained in the PyCall
# documentation, set ENV["PYTHON"] to the path/name of the python executable
# you want to use, run Pkg.build("PyCall"), and re-launch Julia.
#
# ) <class 'ModuleNotFoundError'>
# ModuleNotFoundError("No module named 'wandb'")
#
# Stacktrace:
#   [1] pyimport(name::String)
#     @ PyCall C:\Users\Bikrant\.julia\packages\PyCall\1gn3u\src\PyCall.jl:558
#   [2] __init__()
#     @ WeightsAndBiasLogger C:\Users\Bikrant\.julia\packages\WeightsAndBiasLogger\fr2H9\src\WeightsAndBiasLogger.jl:7
#   [3] run_module_init(mod::Module, i::Int64)
#     @ Base .\loading.jl:1134
#   [4] register_restored_modules(sv::Core.SimpleVector, pkg::Base.PkgId, path::String)
#     @ Base .\loading.jl:1122
#   [5] _include_from_serialized(pkg::Base.PkgId, path::String, ocachepath::String, depmods::Vector{Any})
#     @ Base .\loading.jl:1067
#   [6] _require_search_from_serialized(pkg::Base.PkgId, sourcepath::String, build_id::UInt128)
#     @ Base .\loading.jl:1581
#   [7] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1938
#   [8] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#   [9] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [10] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [11] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#  [12] macro expansion
#     @ .\loading.jl:1790 [inlined]
#  [13] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [14] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#  [15] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [16] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [17] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746
#  [18] include
#     @ .\Base.jl:495 [inlined]
#  [19] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::Nothing)
#     @ Base .\loading.jl:2222
#  [20] top-level scope
#     @ stdin:3
# during initialization of module WeightsAndBiasLogger
# in expression starting at C:\Users\Bikrant\.julia\packages\Crux\thZBC\src\Crux.jl:1
# in expression starting at stdin:
#
# Stacktrace:
#   [1] pkgerror(msg::String)
#     @ Pkg.Types C:\Users\Bikrant\AppData\Local\julias\julia-1.10\share\julia\stdlib\v1.10\Pkg\src\Types.jl:70
#   [2] precompile(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}; internal_call::Bool, strict::Bool, warn_loaded::Bool, already_instantiated::Bool, timing::Bool, _from_loading::Bool, kwargs::@Kwargs{io::IJulia.IJuliaStdio{Base.PipeEndpoint}})
#     @ Pkg.API C:\Users\Bikrant\AppData\Local\julias\julia-1.10\share\julia\stdlib\v1.10\Pkg\src\API.jl:1659
#   [3] precompile(pkgs::Vector{Pkg.Types.PackageSpec}; io::IJulia.IJuliaStdio{Base.PipeEndpoint}, kwargs::@Kwargs{_from_loading::Bool})
#     @ Pkg.API C:\Users\Bikrant\AppData\Local\julias\julia-1.10\share\julia\stdlib\v1.10\Pkg\src\API.jl:159
#   [4] precompile
#     @ C:\Users\Bikrant\AppData\Local\julias\julia-1.10\share\julia\stdlib\v1.10\Pkg\src\API.jl:147 [inlined]
#   [5] #precompile#114
#     @ C:\Users\Bikrant\AppData\Local\julias\julia-1.10\share\julia\stdlib\v1.10\Pkg\src\API.jl:146 [inlined]
#   [6] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [7] invokelatest
#     @ .\essentials.jl:889 [inlined]
#   [8] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1963
#   [9] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#  [10] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [11] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [12] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#  [13] macro expansion
#     @ .\loading.jl:1790 [inlined]
#  [14] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [15] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#  [16] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [17] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [18] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746

# %%
import Pkg; Pkg.add("POMDPTools")
# Out:
#    Resolving package versions...
#     Updating `C:\Users\Bikrant\.julia\environments\v1.10\Project.toml`
# ⌅ [7588e00f] + POMDPTools v0.1.6
#   No Changes to `C:\Users\Bikrant\.julia\environments\v1.10\Manifest.toml`
# Precompiling project...
#   ✓ ADTypes
#   ✓ AdaptivePredicates
#   ✓ FilePathsBase
#   ✓ Einsum
#   ✓ UnsafeArrays
#   ✓ TermInterface
#   ✓ Suppressor
#   ✓ CodeTracking
#   ✓ KLU
#   ✓ Expronicon
#   ✓ QuantumInterface
#   ✓ MutableArithmetics
#   ✓ MUMPS_seq_jll
#   ✓ Hwloc_jll
#   ✓ WeakRefStrings
#   ✓ CodecBzip2
#   ✓ Unityper
#   ✓ TestItemRunner
#   ✓ LinearMaps → LinearMapsChainRulesCoreExt
#   ✓ Accessors
#   ✓ Latexify → DataFramesExt
#   ✓ VertexSafeGraphs
#   ✓ Measurements → MeasurementsUnitfulExt
#   ✓ CommonRLSpaces
#   ✓ StateSpaceSets
#   ✓ DSP
#   ✓ Automa
#   ✓ AbstractDifferentiation → AbstractDifferentiationForwardDiffExt
#   ✓ Packing
#   ✓ IntervalRootFinding
#   ✓ StridedViews → StridedViewsCUDAExt
#   ✓ ShaderAbstractions
#   ✓ FreeTypeAbstraction
#   ✓ GridLayoutBase
#   ✓ BlackBoxOptim
#   ✓ KernelDensity
#   ✓ RandomMatrices
#   ✓ Cairo
#   ✓ SciMLStructures
#   ✓ OnlineStats
#   ✓ MaybeInplace
#   ✓ FiniteDiff
#   ✓ SciMLOperators
#   ✓ ADTypes → ADTypesEnzymeCoreExt
#   ✓ PreallocationTools
#   ✓ StrideArraysCore
#   ✓ FilePaths
#   ✓ UpdateJulia
#   ✓ DelaunayTriangulation
#   ✓ MultivariatePolynomials
#   ✓ SPRAL_jll
#   ✓ JuliaInterpreter
#   ✓ ExponentialUtilities
#   ✓ Accessors → AccessorsIntervalSetsExt
#   ✓ CSV
#   ✓ DelayEmbeddings
#   ✓ RecurrenceAnalysis
#   ✓ Wavelets
#   ✓ AbstractDifferentiation → AbstractDifferentiationZygoteExt
#   ✓ Strided
#   ✓ BlackBoxOptim → BlackBoxOptimRealtimePlotServerExt
#   ✓ ReinforcementLearningTrajectories
#   ✓ FiniteDiff → FiniteDiffStaticArraysExt
#   ✓ MathTeXEngine
#   ✓ ADTypes → ADTypesChainRulesCoreExt
#   ✓ Polyester
#   ✓ Ipopt_jll
#   ✓ DynamicPolynomials
#   ✓ Accessors → AccessorsStructArraysExt
#   ✓ TimeseriesSurrogates
#   ✓ LoweredCodeUtils
#   ✓ AbstractDifferentiation → AbstractDifferentiationChainRulesCoreExt
#   ✓ ComplexityMeasures
#   ✓ NLSolversBase
#   ✓ SparseDiffTools
#   ✓ FastBroadcast
#   ✓ TriangularSolve
#   ✓ Accessors → AccessorsStaticArraysExt
#   ✓ Revise
#   ✓ ExponentialAction
#   ✓ LineSearches
#   ✓ SparseDiffTools → SparseDiffToolsZygoteExt
#   ✓ RecursiveFactorization
#   ✓ Accessors → AccessorsUnitfulExt
#   ✓ Optim
#   ✓ Roots
#   ✓ SymbolicIndexingInterface
#   ✓ Roots → RootsIntervalRootFindingExt
#   ✓ MathOptInterface
#   ✓ RecursiveArrayTools
#   ✓ HypothesisTests
#   ✓ Ipopt
#   ✓ Optim → OptimMOIExt
#   ✓ RecursiveArrayTools → RecursiveArrayToolsForwardDiffExt
#   ✓ SymbolicUtils
#   ✓ FractalDimensions
#   ✓ RecursiveArrayTools → RecursiveArrayToolsZygoteExt
#   ✓ RecursiveArrayTools → RecursiveArrayToolsFastBroadcastExt
#   ✓ SymbolicLimits
#   ✓ RecursiveArrayTools → RecursiveArrayToolsSparseArraysExt
#   ✓ RecursiveArrayTools → RecursiveArrayToolsMeasurementsExt
#   ✓ QuantumOpticsBase
#   ✓ SciMLBase
#   ✓ Makie
#   ✓ DynamicalBilliards → DynamicalBilliardsVisualizations
#   ✓ SciMLBase → SciMLBaseZygoteExt
#   ✓ DomainSets → DomainSetsMakieExt
#   ✓ TimeseriesSurrogates → TimeseriesSurrogatesVisualizations
#   ✓ ReinforcementLearningBase
#   ✓ SciMLBase → SciMLBaseMakieExt
#   ✓ ReinforcementLearningCore
#   ✓ SciMLBase → SciMLBasePyCallExt
#   ✓ ReinforcementLearningEnvironments
#   ✓ CairoMakie
#   ✓ DiffEqBase
#   ✓ ReinforcementLearning
#   ✓ NamedTrajectories
#   ✓ LinearSolve
#   ✓ Symbolics
#   ✓ DiffEqBase → DiffEqBaseCUDAExt
#   ✓ SparseDiffTools → SparseDiffToolsSymbolicsExt
#   ✓ Symbolics → SymbolicsPreallocationToolsExt
#   ✓ SparseDiffTools → SparseDiffToolsPolyesterExt
#   ✓ DiffEqBase → DiffEqBaseUnitfulExt
#   ✓ DiffEqBase → DiffEqBaseChainRulesCoreExt
#   ✓ DiffEqBase → DiffEqBaseMeasurementsExt
#   ✓ LinearSolve → LinearSolveCUDAExt
#   ✓ Symbolics → SymbolicsForwardDiffExt
#   ✓ DiffEqBase → DiffEqBaseSparseArraysExt
#   ✓ DiffEqBase → DiffEqBaseDistributionsExt
#   ✓ SimpleNonlinearSolve
#   ✓ SimpleNonlinearSolve → SimpleNonlinearSolveStaticArraysExt
#   ✓ SimpleNonlinearSolve → SimpleNonlinearSolveZygoteExt
#   ✓ NonlinearSolve
#   ✓ NonlinearSolve → NonlinearSolveSymbolicsExt
#   ✓ NonlinearSolve → NonlinearSolveZygoteExt
#   ✓ DiffEqCallbacks
#   ✓ OrdinaryDiffEq
#   ✓ DynamicalSystemsBase
#   ✓ QuantumToolbox
#   ✓ Attractors
#   ✓ ChaosTools
#   ✓ PredefinedDynamicalSystems
#   ✓ Attractors → AttractorsVisualizations
#   ✓ QuantumToolbox → QuantumToolboxCUDAExt
#   ✓ DynamicalSystems
#   ✓ DynamicalSystems → DynamicalSystemsVisualizations
#   ✓ QuantumCollocation
#   148 dependencies successfully precompiled in 632 seconds. 539 already precompiled. 1 skipped during auto due to previous errors.
