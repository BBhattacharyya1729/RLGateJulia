# %%
using QuantumCollocation
using NamedTrajectories
using TrajectoryIndexingUtils
using Flux
using ReinforcementLearning
using IntervalSets
using LinearAlgebra
using Base
using Distributions
using Statistics
using Printf
using Reexport
using Revise
using DomainSets
using CairoMakie

includet("PPO.jl")
includet("AIRL.jl")
includet("GateEnvs.jl")

# %%
RZ_traj = load_traj("RZ_pretrained.jld2")

const Units = 1e9
const MHz = 1e6 / Units
const GHz = 1e9 / Units
const ns = 1e-9 * Units
const μs = 1e-6 * Units
;


# Operators
const Paulis = Dict(
    "I" => Matrix{ComplexF64}([1 0; 0 1]),
    "X" => Matrix{ComplexF64}([0 1; 1 0]),
    "Y" => Matrix{ComplexF64}([0 im; -im 0]),
    "Z" => Matrix{ComplexF64}([1 0; 0 -1]),
)

rz_op(theta) = exp(-im/2 * theta[1] * Paulis["Z"]);

RZ = Gate(1,rz_op)

H_drives = [
     Paulis["X"],Paulis["Y"]
]
system = QuantumSystem(H_drives);
t_f = 10* ns
n_steps = 51
times = range(0, t_f, n_steps)  # Alternative: collect(0:Δt:t_f)
n_controls=1
n_qubits=1;
Δt = times[2] - times[1]

N = 11
;

# %%
Pretraining_Env = GatePretrainingEnv(
                                    system,
                                    n_steps,
                                    RZ,
                                    Δt,
                                    N,
                                    RZ_traj;
                                    dda_bound=1.5
                                    )
pretraining_𝒫 = ActorCriticPolicy(Pretraining_Env;)
pretraining_bc_𝒫 = ActorCriticPolicy(Pretraining_Env;)
load_policy(pretraining_𝒫,"initial_policy.jld2")
load_policy(pretraining_bc_𝒫,"bc_policy.jld2")
# Out:
# ActorCriticPolicy(Chain(Dense(14 => 128, tanh), Dense(128 => 128, tanh)), Dense(128 => 2, tanh), Dense(128 => 1, log_std_clip), Chain(Dense(14 => 128, tanh), Dense(128 => 128, tanh), Dense(128 => 1)))

# %%
fig = Figure()
infid_data = policy_sample(Pretraining_Env,pretraining_𝒫,100)
infid_data1 = policy_sample(Pretraining_Env,pretraining_bc_𝒫,100)
ax = Axis(fig[1, 1])
l = lines!(ax,range(0,2π,length(infid_data)),log10.(infid_data))
l1 = lines!(ax,range(0,2π,length(infid_data1)),log10.(infid_data1))
Legend(fig[1, 2],
    [l, l1],
    ["Random", "BC"])
fig

# %%
PPO_pretraining_𝒫,score_history = PPO(Pretraining_Env;η=3f-5,iterations=50,n_steps=1,trajectory_batch_size=40,vf_ratio=5f-1,norm_adv = true,ϵ= 2f-1,ent_ratio=1f-2,KL_targ=5f-2,initial_policy=pretraining_𝒫,clip_grad_tresh=5f-1,use_log_rewards=false)
# Out:
# TypeError: in keyword argument clip_grad_tresh, expected Float32, got a value of type Float64
#
# Stacktrace:
#  [1] top-level scope
#    @ In[5]:1

# %%
PPO_pretraining_bc_𝒫,bc_score_history = PPO(Pretraining_Env;η=3f-5,iterations=50,n_steps=1,trajectory_batch_size=40,vf_ratio=5f-1,norm_adv = true,ϵ= 2f-1,ent_ratio=1f-2,KL_targ=5f-2,initial_policy=pretraining_bc_𝒫,clip_grad_tresh=5f-1,use_log_rewards=false)
# Out:
# TypeError: in keyword argument clip_grad_tresh, expected Float32, got a value of type Float64
#
# Stacktrace:
#  [1] top-level scope
#    @ In[6]:1

# %%
fig = Figure()
ax = Axis(fig[1, 1])
l = lines!(ax,1:length(score_history),score_history)
l1 = lines!(ax,1:length(score_history),bc_score_history)
Legend(fig[1, 2],
    [l, l1],
    ["Random", "BC"])
fig
# Out:
# UndefVarError: `score_history` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[7]:3

# %%
fig = Figure()
infid_data = policy_sample(Pretraining_Env,PPO_pretraining_𝒫,100)
infid_data1 = policy_sample(Pretraining_Env,PPO_pretraining_bc_𝒫,100)
ax = Axis(fig[1, 1])
l = lines!(ax,range(0,2π,length(infid_data)),log10.(infid_data))
l1 = lines!(ax,range(0,2π,length(infid_data1)),log10.(infid_data1))
Legend(fig[1, 2],
    [l, l1],
    ["Random", "BC"])
fig
# Out:
# UndefVarError: `PPO_pretraining_𝒫` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[8]:2
