# %%
using QuantumCollocation
using NamedTrajectories
using TrajectoryIndexingUtils
using CairoMakie

# %%
RZ_traj = load_traj("RZ_pretrained.jld2")
U2_traj = load_traj("U2_pretrained.jld2")
;

# %%
const Units = 1e9
const MHz = 1e6 / Units
const GHz = 1e9 / Units
const ns = 1e-9 * Units
const μs = 1e-6 * Units
;

# %%
# Operators
const Paulis = Dict(
    "I" => Matrix{ComplexF64}([1 0; 0 1]),
    "X" => Matrix{ComplexF64}([0 1; 1 0]),
    "Y" => Matrix{ComplexF64}([0 im; -im 0]),
    "Z" => Matrix{ComplexF64}([1 0; 0 -1]),
)
const a = [0 1; 0 0]
const ad = transpose(a);
rz_op(theta) = exp(-im/2 * theta[1] * Paulis["Z"]);

RZ = Gate(1,rz_op)

u2_op(theta) = 1/sqrt(2) * [1 -exp(1im * theta[2]);exp(1im * theta[1]) exp(1im * (theta[1]+theta[2]))]

U2 = Gate(2,u2_op)
U2([1,2])

H_drives = [
     Paulis["X"],Paulis["Y"]
]
system = QuantumSystem(H_drives);
t_f = 10* ns
n_steps = 51
times = range(0, t_f, n_steps)  # Alternative: collect(0:Δt:t_f)
n_controls=1
n_qubits=1;
Δt = times[2] - times[1]

N = 11
;
# Out:
# WARNING: redefinition of constant Main.Paulis. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant Main.a. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant Main.ad. This may fail, cause incorrect answers, or produce other errors.

# %%
RZ_data = sample(RZ_traj,RZ,Δt,system,100,N)
U2_data = sample(U2_traj,U2,Δt,system,100,N)
;

# %%
lines(range(0,2*pi,100),log10.(RZ_data))

# %%
fig, ax, hm = heatmap(range(0,2*pi,100),range(0,2*pi,100),log10.(U2_data),colormap=:inferno)
Colorbar(fig[:, end+1], hm)

fig

# %%
sum(log10.(RZ_data))/100
# Out:
# -4.082233528858827

# %%
sum(log10.(U2_data))/100^2
# Out:
# -3.321516961188823

# %%
RZ_data = phase_sample(RZ_traj,RZ,Δt,system,100,N)
U2_data = phase_sample(U2_traj,U2,Δt,system,100,N)
;

# %%
lines(range(0,2*pi,100),(RZ_data))

# %%
fig, ax, hm = heatmap(range(0,2*pi,100),range(0,2*pi,100),(U2_data),colormap=:inferno)
Colorbar(fig[:, end+1], hm)

fig
